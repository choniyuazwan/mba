# %% [markdown]
# # Market Basket Analysis

# %% [markdown]
# ### Prepare csv file

# %%
import pandas as pd

# %%
df = pd.read_excel('Persona.xlsx', sheet_name='Market Basket')

# %%
df.head()
# Out:
#    Transaction_ID  CardNo       Prod1       Prod2    Prod3   Prod4    Prod5
# 0               1      83       kurma     alpokat    kurma  pisang     sawo
# 1               2      31  naga merah  naga merah    jambu  Anggur  alpokat
# 2               3       1      pisang         pir  alpokat   jambu    jambu
# 3               4      51        sawo  naga merah    Jeruk    sawo   pisang
# 4               5      85     alpokat         pir  alpokat  mangga   Anggur

# %%
df.shape
# Out:
# (199, 7)

# %%
df.to_csv('persona_market_basket.csv', index=False)

# %% [markdown]
# ### read data from csv

# %% [markdown]
# ##### https://medium.com/@hafizhan.aliady/market-basket-analysis-acossiation-rule-menggunakan-python-1012f9e1611d
# ##### https://pbpython.com/market-basket-analysis.html

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv('persona_market_basket.csv')

# %%
df.head()
# Out:
#    Transaction_ID  CardNo       Prod1       Prod2    Prod3   Prod4    Prod5
# 0               1      83       kurma     alpokat    kurma  pisang     sawo
# 1               2      31  naga merah  naga merah    jambu  Anggur  alpokat
# 2               3       1      pisang         pir  alpokat   jambu    jambu
# 3               4      51        sawo  naga merah    Jeruk    sawo   pisang
# 4               5      85     alpokat         pir  alpokat  mangga   Anggur

# %%
df.shape
# Out:
# (199, 7)

# %% [markdown]
# ### remove transaction_id and CardNo column

# %%
df = df.drop(df.columns[[0, 1]], axis=1)

# %%
df.head()
# Out:
#         Prod1       Prod2    Prod3   Prod4    Prod5
# 0       kurma     alpokat    kurma  pisang     sawo
# 1  naga merah  naga merah    jambu  Anggur  alpokat
# 2      pisang         pir  alpokat   jambu    jambu
# 3        sawo  naga merah    Jeruk    sawo   pisang
# 4     alpokat         pir  alpokat  mangga   Anggur

# %% [markdown]
# ### check are there any null value

# %%
print(df.isna().sum())
# Out:
# Prod1    0
# Prod2    0
# Prod3    0
# Prod4    0
# Prod5    0
# dtype: int64

# %%
# convert pandas dataframe to list
records = []
for i in range(0, df.shape[0]):
    records.append([str(df.values[i,j]) for j in range(0, df.shape[1])])

# %%
records
# Out:
# [['kurma', 'alpokat', 'kurma', 'pisang', 'sawo'],
#  ['naga merah', 'naga merah', 'jambu', 'Anggur', 'alpokat'],
#  ['pisang', 'pir', 'alpokat', 'jambu', 'jambu'],
#  ['sawo', 'naga merah', 'Jeruk', 'sawo', 'pisang'],
#  ['alpokat', 'pir', 'alpokat', 'mangga', 'Anggur'],
#  ['kurma', 'sawo', 'kurma', 'mangga', 'mangga'],
#  ['mangga', 'kurma', 'Jeruk', 'alpokat', 'sawo'],
#  ['Jeruk', 'Jeruk', 'sawo', 'Jeruk', 'naga merah'],
#  ['Jeruk', 'Jeruk', 'mangga', 'naga merah', 'naga merah'],
#  ['mangga', 'Anggur', 'jambu', 'alpokat', 'naga merah'],
#  ['Jeruk', 'jambu', 'sawo', 'sawo', 'kurma'],
#  ['pir', 'mangga', 'pir', 'Anggur', 'naga merah'],
#  ['naga merah', 'jambu', 'Jeruk', 'jambu', 'Jeruk'],
#  ['pir', 'naga merah', 'alpokat', 'Anggur', 'Anggur'],
#  ['Anggur', 'naga merah', 'pir', 'pisang', 'pir'],
#  ['pisang', 'alpokat', 'pisang', 'kurma', 'Jeruk'],
#  ['mangga', 'Anggur', 'mangga', 'mangga', 'mangga'],
#  ['pir', 'jambu', 'sawo', 'mangga', 'kurma'],
#  ['naga merah', 'Jeruk', 'kurma', 'naga merah', 'sawo'],
#  ['mangga', 'alpokat', 'Anggur', 'sawo', 'pisang'],
#  ['jambu', 'kurma', 'Anggur', 'kurma', 'sawo'],
#  ['sawo', 'sawo', 'pir', 'kurma', 'alpokat'],
#  ['kurma', 'sawo', 'naga merah', 'sawo', 'kurma'],
#  ['jambu', 'alpokat', 'pisang', 'pisang', 'mangga'],
#  ['mangga', 'jambu', 'pir', 'kurma', 'pir'],
#  ['Jeruk', 'Anggur', 'alpokat', 'naga merah', 'sawo'],
#  ['alpokat', 'pisang', 'Anggur', 'Anggur', 'jambu'],
#  ['mangga', 'pir', 'pir', 'sawo', 'naga merah'],
#  ['kurma', 'jambu', 'pisang', 'jambu', 'pir'],
#  ['alpokat', 'Anggur', 'naga merah', 'naga merah', 'pisang'],
#  ['pisang', 'pisang', 'naga merah', 'sawo', 'jambu'],
#  ['pisang', 'sawo', 'naga merah', 'Anggur', 'pir'],
#  ['Jeruk', 'pisang', 'naga merah', 'naga merah', 'sawo'],
#  ['naga merah', 'Anggur', 'sawo', 'pisang', 'alpokat'],
#  ['naga merah', 'jambu', 'sawo', 'pisang', 'pisang'],
#  ['pisang', 'naga merah', 'alpokat', 'Anggur', 'sawo'],
#  ['mangga', 'pir', 'pir', 'pir', 'Anggur'],
#  ['naga merah', 'Anggur', 'pir', 'pisang', 'jambu'],
#  ['sawo', 'alpokat', 'pir', 'jambu', 'Anggur'],
#  ['naga merah', 'mangga', 'alpokat', 'pisang', 'pisang'],
#  ['jambu', 'mangga', 'kurma', 'sawo', 'kurma'],
#  ['Anggur', 'jambu', 'sawo', 'Jeruk', 'pisang'],
#  ['kurma', 'Jeruk', 'naga merah', 'Jeruk', 'jambu'],
#  ['kurma', 'alpokat', 'sawo', 'jambu', 'alpokat'],
#  ['sawo', 'Jeruk', 'naga merah', 'alpokat', 'jambu'],
#  ['jambu', 'pir', 'alpokat', 'pir', 'Jeruk'],
#  ['sawo', 'alpokat', 'sawo', 'Anggur', 'kurma'],
#  ['sawo', 'naga merah', 'naga merah', 'naga merah', 'pir'],
#  ['mangga', 'Jeruk', 'kurma', 'alpokat', 'pisang'],
#  ['jambu', 'jambu', 'kurma', 'pir', 'pir'],
#  ['mangga', 'Anggur', 'pisang', 'pisang', 'jambu'],
#  ['Jeruk', 'alpokat', 'alpokat', 'Jeruk', 'pir'],
#  ['sawo', 'alpokat', 'Jeruk', 'sawo', 'pir'],
#  ['pir', 'mangga', 'alpokat', 'pir', 'sawo'],
#  ['Anggur', 'Jeruk', 'kurma', 'Jeruk', 'jambu'],
#  ['jambu', 'pir', 'pir', 'pisang', 'Anggur'],
#  ['kurma', 'Anggur', 'sawo', 'pisang', 'mangga'],
#  ['pir', 'Anggur', 'Jeruk', 'naga merah', 'alpokat'],
#  ['alpokat', 'mangga', 'pisang', 'pisang', 'jambu'],
#  ['Anggur', 'pir', 'kurma', 'sawo', 'Anggur'],
#  ['mangga', 'sawo', 'Jeruk', 'sawo', 'mangga'],
#  ['pir', 'sawo', 'mangga', 'Jeruk', 'mangga'],
#  ['mangga', 'sawo', 'jambu', 'naga merah', 'pisang'],
#  ['sawo', 'Jeruk', 'jambu', 'alpokat', 'pisang'],
#  ['Anggur', 'Anggur', 'pisang', 'jambu', 'Jeruk'],
#  ['naga merah', 'pisang', 'Anggur', 'sawo', 'mangga'],
#  ['pisang', 'jambu', 'pisang', 'Anggur', 'alpokat'],
#  ['kurma', 'pisang', 'Jeruk', 'pisang', 'Anggur'],
#  ['alpokat', 'pir', 'pir', 'Anggur', 'pir'],
#  ['Jeruk', 'jambu', 'sawo', 'alpokat', 'Jeruk'],
#  ['sawo', 'kurma', 'pisang', 'Jeruk', 'Jeruk'],
#  ['alpokat', 'jambu', 'Anggur', 'pisang', 'mangga'],
#  ['mangga', 'kurma', 'mangga', 'mangga', 'Jeruk'],
#  ['sawo', 'pir', 'Jeruk', 'kurma', 'kurma'],
#  ['Anggur', 'pisang', 'kurma', 'mangga', 'sawo'],
#  ['Jeruk', 'mangga', 'Jeruk', 'pir', 'pir'],
#  ['Anggur', 'Anggur', 'sawo', 'Anggur', 'kurma'],
#  ['naga merah', 'Anggur', 'Jeruk', 'sawo', 'jambu'],
#  ['pisang', 'pisang', 'pisang', 'kurma', 'jambu'],
#  ['mangga', 'Anggur', 'naga merah', 'pisang', 'naga merah'],
#  ['jambu', 'naga merah', 'jambu', 'pisang', 'pisang'],
#  ['naga merah', 'Jeruk', 'jambu', 'Anggur', 'alpokat'],
#  ['pisang', 'mangga', 'Anggur', 'mangga', 'kurma'],
#  ['kurma', 'naga merah', 'kurma', 'alpokat', 'Jeruk'],
#  ['Jeruk', 'jambu', 'pisang', 'pisang', 'sawo'],
#  ['kurma', 'Jeruk', 'naga merah', 'kurma', 'alpokat'],
#  ['pisang', 'alpokat', 'alpokat', 'kurma', 'kurma'],
#  ['sawo', 'naga merah', 'Anggur', 'kurma', 'pisang'],
#  ['jambu', 'alpokat', 'sawo', 'pir', 'alpokat'],
#  ['Anggur', 'pir', 'pir', 'Jeruk', 'mangga'],
#  ['kurma', 'kurma', 'kurma', 'Anggur', 'kurma'],
#  ['mangga', 'Jeruk', 'jambu', 'Anggur', 'pisang'],
#  ['kurma', 'alpokat', 'pir', 'pir', 'pir'],
#  ['pisang', 'jambu', 'alpokat', 'kurma', 'naga merah'],
#  ['mangga', 'Jeruk', 'naga merah', 'alpokat', 'Anggur'],
#  ['Jeruk', 'mangga', 'Anggur', 'pisang', 'pisang'],
#  ['kurma', 'mangga', 'kurma', 'naga merah', 'naga merah'],
#  ['sawo', 'jambu', 'mangga', 'jambu', 'pir'],
#  ['jambu', 'naga merah', 'Jeruk', 'kurma', 'jambu'],
#  ['mangga', 'sawo', 'Jeruk', 'alpokat', 'Jeruk'],
#  ['mangga', 'sawo', 'mangga', 'alpokat', 'sawo'],
#  ['kurma', 'Anggur', 'Jeruk', 'sawo', 'sawo'],
#  ['pir', 'Jeruk', 'Anggur', 'kurma', 'naga merah'],
#  ['naga merah', 'naga merah', 'mangga', 'Anggur', 'naga merah'],
#  ['kurma', 'pisang', 'jambu', 'Jeruk', 'naga merah'],
#  ['naga merah', 'naga merah', 'sawo', 'mangga', 'mangga'],
#  ['pisang', 'kurma', 'alpokat', 'kurma', 'mangga'],
#  ['pir', 'jambu', 'sawo', 'mangga', 'Anggur'],
#  ['Jeruk', 'kurma', 'jambu', 'jambu', 'pir'],
#  ['mangga', 'pisang', 'sawo', 'alpokat', 'alpokat'],
#  ['kurma', 'Anggur', 'alpokat', 'Jeruk', 'mangga'],
#  ['pir', 'Anggur', 'pisang', 'mangga', 'jambu'],
#  ['Jeruk', 'pir', 'mangga', 'naga merah', 'pisang'],
#  ['jambu', 'kurma', 'jambu', 'jambu', 'jambu'],
#  ['sawo', 'Anggur', 'pir', 'naga merah', 'Anggur'],
#  ['jambu', 'mangga', 'pir', 'pisang', 'naga merah'],
#  ['Anggur', 'alpokat', 'naga merah', 'mangga', 'kurma'],
#  ['Anggur', 'sawo', 'Jeruk', 'pisang', 'kurma'],
#  ['Jeruk', 'sawo', 'pir', 'pir', 'mangga'],
#  ['kurma', 'Jeruk', 'mangga', 'pisang', 'mangga'],
#  ['Jeruk', 'jambu', 'sawo', 'sawo', 'mangga'],
#  ['jambu', 'sawo', 'alpokat', 'Anggur', 'Jeruk'],
#  ['naga merah', 'kurma', 'jambu', 'pir', 'sawo'],
#  ['pir', 'jambu', 'jambu', 'Jeruk', 'sawo'],
#  ['mangga', 'pir', 'kurma', 'jambu', 'naga merah'],
#  ['pir', 'Anggur', 'jambu', 'kurma', 'alpokat'],
#  ['pisang', 'sawo', 'Anggur', 'mangga', 'kurma'],
#  ['naga merah', 'pir', 'pisang', 'Anggur', 'jambu'],
#  ['alpokat', 'pir', 'jambu', 'Jeruk', 'Jeruk'],
#  ['pir', 'Anggur', 'jambu', 'Jeruk', 'kurma'],
#  ['naga merah', 'pisang', 'mangga', 'alpokat', 'kurma'],
#  ['sawo', 'Anggur', 'pisang', 'Anggur', 'sawo'],
#  ['jambu', 'pir', 'mangga', 'sawo', 'pir'],
#  ['alpokat', 'kurma', 'naga merah', 'alpokat', 'pir'],
#  ['naga merah', 'naga merah', 'jambu', 'kurma', 'mangga'],
#  ['alpokat', 'alpokat', 'kurma', 'pir', 'jambu'],
#  ['pir', 'jambu', 'mangga', 'jambu', 'naga merah'],
#  ['pir', 'sawo', 'Jeruk', 'mangga', 'pisang'],
#  ['kurma', 'naga merah', 'alpokat', 'mangga', 'sawo'],
#  ['Anggur', 'naga merah', 'pisang', 'naga merah', 'jambu'],
#  ['sawo', 'kurma', 'Anggur', 'Jeruk', 'pisang'],
#  ['kurma', 'Jeruk', 'pir', 'alpokat', 'jambu'],
#  ['kurma', 'pir', 'Anggur', 'mangga', 'mangga'],
#  ['alpokat', 'kurma', 'sawo', 'pir', 'pir'],
#  ['pisang', 'Jeruk', 'alpokat', 'Anggur', 'naga merah'],
#  ['Anggur', 'pir', 'pir', 'pir', 'Anggur'],
#  ['naga merah', 'jambu', 'kurma', 'alpokat', 'alpokat'],
#  ['Anggur', 'alpokat', 'jambu', 'Jeruk', 'naga merah'],
#  ['pir', 'alpokat', 'pisang', 'Anggur', 'kurma'],
#  ['pir', 'sawo', 'pir', 'alpokat', 'pisang'],
#  ['Anggur', 'pir', 'sawo', 'mangga', 'Jeruk'],
#  ['Jeruk', 'Jeruk', 'jambu', 'alpokat', 'Jeruk'],
#  ['alpokat', 'kurma', 'Anggur', 'Anggur', 'sawo'],
#  ['Anggur', 'alpokat', 'naga merah', 'pisang', 'jambu'],
#  ['naga merah', 'naga merah', 'pisang', 'kurma', 'pisang'],
#  ['sawo', 'pisang', 'jambu', 'mangga', 'mangga'],
#  ['pir', 'Jeruk', 'naga merah', 'kurma', 'kurma'],
#  ['Jeruk', 'mangga', 'Jeruk', 'pir', 'mangga'],
#  ['jambu', 'sawo', 'naga merah', 'pisang', 'jambu'],
#  ['pir', 'Anggur', 'kurma', 'sawo', 'pir'],
#  ['jambu', 'sawo', 'Anggur', 'kurma', 'alpokat'],
#  ['Anggur', 'kurma', 'jambu', 'kurma', 'kurma'],
#  ['naga merah', 'kurma', 'naga merah', 'pisang', 'Jeruk'],
#  ['Jeruk', 'mangga', 'pisang', 'alpokat', 'alpokat'],
#  ['Jeruk', 'naga merah', 'naga merah', 'sawo', 'pisang'],
#  ['pir', 'sawo', 'pisang', 'pir', 'Anggur'],
#  ['jambu', 'kurma', 'Jeruk', 'alpokat', 'alpokat'],
#  ['jambu', 'jambu', 'Anggur', 'jambu', 'naga merah'],
#  ['Anggur', 'mangga', 'Jeruk', 'pisang', 'kurma'],
#  ['sawo', 'mangga', 'Anggur', 'alpokat', 'naga merah'],
#  ['kurma', 'Jeruk', 'pisang', 'alpokat', 'pir'],
#  ['Jeruk', 'alpokat', 'naga merah', 'alpokat', 'kurma'],
#  ['Anggur', 'Anggur', 'sawo', 'naga merah', 'pir'],
#  ['naga merah', 'alpokat', 'jambu', 'naga merah', 'pisang'],
#  ['pisang', 'jambu', 'naga merah', 'Jeruk', 'sawo'],
#  ['sawo', 'pisang', 'jambu', 'pir', 'Anggur'],
#  ['pir', 'pir', 'pisang', 'naga merah', 'pir'],
#  ['kurma', 'mangga', 'naga merah', 'mangga', 'sawo'],
#  ['kurma', 'kurma', 'naga merah', 'mangga', 'pir'],
#  ['naga merah', 'jambu', 'Jeruk', 'mangga', 'mangga'],
#  ['naga merah', 'mangga', 'Anggur', 'pisang', 'naga merah'],
#  ['jambu', 'kurma', 'kurma', 'pisang', 'Anggur'],
#  ['alpokat', 'mangga', 'pisang', 'jambu', 'sawo'],
#  ['Anggur', 'naga merah', 'Jeruk', 'pir', 'alpokat'],
#  ['naga merah', 'jambu', 'Jeruk', 'mangga', 'kurma'],
#  ['jambu', 'jambu', 'naga merah', 'pisang', 'sawo'],
#  ['alpokat', 'jambu', 'pir', 'mangga', 'Jeruk'],
#  ['Anggur', 'naga merah', 'Anggur', 'pir', 'pir'],
#  ['Anggur', 'pir', 'mangga', 'Anggur', 'Jeruk'],
#  ['sawo', 'pir', 'Jeruk', 'pisang', 'Jeruk'],
#  ['alpokat', 'pisang', 'naga merah', 'sawo', 'pisang'],
#  ['sawo', 'mangga', 'jambu', 'alpokat', 'mangga'],
#  ['mangga', 'Anggur', 'kurma', 'kurma', 'Jeruk'],
#  ['sawo', 'sawo', 'naga merah', 'jambu', 'pir'],
#  ['kurma', 'sawo', 'pir', 'alpokat', 'naga merah'],
#  ['alpokat', 'jambu', 'kurma', 'naga merah', 'Jeruk'],
#  ['pir', 'alpokat', 'alpokat', 'jambu', 'sawo'],
#  ['jambu', 'mangga', 'mangga', 'sawo', 'pisang'],
#  ['alpokat', 'pisang', 'pisang', 'pisang', 'mangga']]

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df_transform = pd.DataFrame(te_ary, columns=te.columns_)
df_transform
# Out:
#      Anggur  Jeruk  alpokat  jambu  kurma  mangga  naga merah    pir  pisang  \
# 0     False  False     True  False   True   False       False  False    True
# 1      True  False     True   True  False   False        True  False   False
# 2     False  False     True   True  False   False       False   True    True
# 3     False   True    False  False  False   False        True  False    True
# 4      True  False     True  False  False    True       False   True   False
# 5     False  False    False  False   True    True       False  False   False
# 6     False   True     True  False   True    True       False  False   False
# 7     False   True    False  False  False   False        True  False   False
# 8     False   True    False  False  False    True        True  False   False
# 9      True  False     True   True  False    True        True  False   False
# 10    False   True    False   True   True   False       False  False   False
# 11     True  False    False  False  False    True        True   True   False
# 12    False   True    False   True  False   False        True  False   False
# 13     True  False     True  False  False   False        True   True   False
# 14     True  False    False  False  False   False        True   True    True
# 15    False   True     True  False   True   False       False  False    True
# 16     True  False    False  False  False    True       False  False   False
# 17    False  False    False   True   True    True       False   True   False
# 18    False   True    False  False   True   False        True  False   False
# 19     True  False     True  False  False    True       False  False    True
# 20     True  False    False   True   True   False       False  False   False
# 21    False  False     True  False   True   False       False   True   False
# 22    False  False    False  False   True   False        True  False   False
# 23    False  False     True   True  False    True       False  False    True
# 24    False  False    False   True   True    True       False   True   False
# 25     True   True     True  False  False   False        True  False   False
# 26     True  False     True   True  False   False       False  False    True
# 27    False  False    False  False  False    True        True   True   False
# 28    False  False    False   True   True   False       False   True    True
# 29     True  False     True  False  False   False        True  False    True
# ..      ...    ...      ...    ...    ...     ...         ...    ...     ...
# 169    True  False     True  False  False    True        True  False   False
# 170   False   True     True  False   True   False       False   True    True
# 171   False   True     True  False   True   False        True  False   False
# 172    True  False    False  False  False   False        True   True   False
# 173   False  False     True   True  False   False        True  False    True
# 174   False   True    False   True  False   False        True  False    True
# 175    True  False    False   True  False   False       False   True    True
# 176   False  False    False  False  False   False        True   True    True
# 177   False  False    False  False   True    True        True  False   False
# 178   False  False    False  False   True    True        True   True   False
# 179   False   True    False   True  False    True        True  False   False
# 180    True  False    False  False  False    True        True  False    True
# 181    True  False    False   True   True   False       False  False    True
# 182   False  False     True   True  False    True       False  False    True
# 183    True   True     True  False  False   False        True   True   False
# 184   False   True    False   True   True    True        True  False   False
# 185   False  False    False   True  False   False        True  False    True
# 186   False   True     True   True  False    True       False   True   False
# 187    True  False    False  False  False   False        True   True   False
# 188    True   True    False  False  False    True       False   True   False
# 189   False   True    False  False  False   False       False   True    True
# 190   False  False     True  False  False   False        True  False    True
# 191   False  False     True   True  False    True       False  False   False
# 192    True   True    False  False   True    True       False  False   False
# 193   False  False    False   True  False   False        True   True   False
# 194   False  False     True  False   True   False        True   True   False
# 195   False   True     True   True   True   False        True  False   False
# 196   False  False     True   True  False   False       False   True   False
# 197   False  False    False   True  False    True       False  False    True
# 198   False  False     True  False  False    True       False  False    True
#
#       sawo
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# 8    False
# 9    False
# 10    True
# 11   False
# 12   False
# 13   False
# 14   False
# 15   False
# 16   False
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23   False
# 24   False
# 25    True
# 26   False
# 27    True
# 28   False
# 29   False
# ..     ...
# 169   True
# 170  False
# 171  False
# 172   True
# 173  False
# 174   True
# 175   True
# 176  False
# 177   True
# 178  False
# 179  False
# 180  False
# 181  False
# 182   True
# 183  False
# 184  False
# 185   True
# 186  False
# 187  False
# 188  False
# 189   True
# 190   True
# 191   True
# 192  False
# 193   True
# 194   True
# 195  False
# 196   True
# 197   True
# 198  False
#
# [199 rows x 10 columns]

# %%
df_transform.shape
# Out:
# (199, 10)

# %%
df_transform.dtypes
# Out:
# Anggur        bool
# Jeruk         bool
# alpokat       bool
# jambu         bool
# kurma         bool
# mangga        bool
# naga merah    bool
# pir           bool
# pisang        bool
# sawo          bool
# dtype: object

# %%
# Build up the frequent items# Build  
frequent_itemsets = apriori(df_transform, min_support=0, use_colnames=True)

# %%
frequent_itemsets.shape
# Out:
# (1023, 2)

# %%
frequent_itemsets.head()
# Out:
#     support   itemsets
# 0  0.422111   (Anggur)
# 1  0.396985    (Jeruk)
# 2  0.402010  (alpokat)
# 3  0.437186    (jambu)
# 4  0.412060    (kurma)

# %%
many_bundling = 4
for index, row in frequent_itemsets.iterrows():
    if(len(row['itemsets']) == many_bundling):
        result_bundling = frequent_itemsets.loc[[index]]
        break

result_bundling
# Out:
#       support                         itemsets
# 175  0.015075  (alpokat, jambu, Jeruk, Anggur)

# %%
len(bundling)
# Out:
# 120

# %%
frequent_itemsets.loc[[174]]
# Out:
#       support             itemsets
# 174  0.030151  (pisang, pir, sawo)

# %%
frequent_itemsets.loc[[55]]
# Out:
#      support                  itemsets
# 55  0.045226  (alpokat, Jeruk, Anggur)

# %%
bundling
# Out:
# [55,
#  56,
#  57,
#  58,
#  59,
#  60,
#  61,
#  62,
#  63,
#  64,
#  65,
#  66,
#  67,
#  68,
#  69,
#  70,
#  71,
#  72,
#  73,
#  74,
#  75,
#  76,
#  77,
#  78,
#  79,
#  80,
#  81,
#  82,
#  83,
#  84,
#  85,
#  86,
#  87,
#  88,
#  89,
#  90,
#  91,
#  92,
#  93,
#  94,
#  95,
#  96,
#  97,
#  98,
#  99,
#  100,
#  101,
#  102,
#  103,
#  104,
#  105,
#  106,
#  107,
#  108,
#  109,
#  110,
#  111,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  138,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  151,
#  152,
#  153,
#  154,
#  155,
#  156,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174]

# %%
frequent_itemsets.to_csv('frequent_itemsets.csv', index=False)

# %%
frequent_itemsets
# Out:
#        support                                           itemsets
# 0     0.422111                                           (Anggur)
# 1     0.396985                                            (Jeruk)
# 2     0.402010                                          (alpokat)
# 3     0.437186                                            (jambu)
# 4     0.412060                                            (kurma)
# 5     0.391960                                           (mangga)
# 6     0.422111                                       (naga merah)
# 7     0.376884                                              (pir)
# 8     0.417085                                           (pisang)
# 9     0.447236                                             (sawo)
# 10    0.130653                                    (Jeruk, Anggur)
# 11    0.150754                                  (alpokat, Anggur)
# 12    0.150754                                    (jambu, Anggur)
# 13    0.145729                                    (kurma, Anggur)
# 14    0.150754                                   (mangga, Anggur)
# 15    0.165829                               (Anggur, naga merah)
# 16    0.155779                                      (Anggur, pir)
# 17    0.190955                                   (pisang, Anggur)
# 18    0.160804                                     (Anggur, sawo)
# 19    0.150754                                   (Jeruk, alpokat)
# 20    0.155779                                     (Jeruk, jambu)
# 21    0.165829                                     (kurma, Jeruk)
# 22    0.135678                                    (mangga, Jeruk)
# 23    0.150754                                (Jeruk, naga merah)
# 24    0.125628                                       (Jeruk, pir)
# 25    0.130653                                    (pisang, Jeruk)
# 26    0.155779                                      (Jeruk, sawo)
# 27    0.170854                                   (jambu, alpokat)
# 28    0.155779                                   (kurma, alpokat)
# 29    0.125628                                  (mangga, alpokat)
# ...        ...                                                ...
# 993   0.000000  (jambu, naga merah, pir, sawo, mangga, pisang,...
# 994   0.000000  (kurma, naga merah, pir, sawo, mangga, pisang,...
# 995   0.000000  (kurma, alpokat, jambu, naga merah, pir, mangg...
# 996   0.000000  (kurma, alpokat, jambu, naga merah, pir, sawo,...
# 997   0.000000  (kurma, alpokat, jambu, naga merah, sawo, mang...
# 998   0.000000  (kurma, alpokat, jambu, pir, sawo, mangga, pis...
# 999   0.000000  (kurma, alpokat, jambu, naga merah, pir, sawo,...
# 1000  0.000000  (alpokat, jambu, naga merah, pir, sawo, mangga...
# 1001  0.000000  (kurma, alpokat, naga merah, pir, sawo, mangga...
# 1002  0.000000  (kurma, jambu, naga merah, pir, sawo, mangga, ...
# 1003  0.000000  (kurma, jambu, alpokat, naga merah, pir, mangg...
# 1004  0.000000  (kurma, jambu, alpokat, naga merah, pir, sawo,...
# 1005  0.000000  (kurma, jambu, alpokat, naga merah, sawo, mang...
# 1006  0.000000  (kurma, jambu, alpokat, pir, sawo, mangga, pis...
# 1007  0.000000  (kurma, jambu, alpokat, naga merah, pir, sawo,...
# 1008  0.000000  (jambu, alpokat, naga merah, pir, sawo, mangga...
# 1009  0.000000  (kurma, alpokat, naga merah, pir, sawo, mangga...
# 1010  0.000000  (kurma, jambu, naga merah, pir, sawo, mangga, ...
# 1011  0.000000  (kurma, jambu, alpokat, naga merah, pir, sawo,...
# 1012  0.000000  (kurma, alpokat, jambu, naga merah, pir, mangg...
# 1013  0.000000  (kurma, alpokat, jambu, naga merah, pir, sawo,...
# 1014  0.000000  (kurma, alpokat, jambu, naga merah, sawo, mang...
# 1015  0.000000  (kurma, alpokat, jambu, pir, sawo, mangga, pis...
# 1016  0.000000  (kurma, alpokat, jambu, naga merah, pir, sawo,...
# 1017  0.000000  (alpokat, jambu, naga merah, pir, sawo, mangga...
# 1018  0.000000  (kurma, alpokat, naga merah, pir, sawo, mangga...
# 1019  0.000000  (kurma, jambu, naga merah, pir, sawo, mangga, ...
# 1020  0.000000  (kurma, alpokat, jambu, naga merah, pir, sawo,...
# 1021  0.000000  (kurma, jambu, alpokat, naga merah, pir, sawo,...
# 1022  0.000000  (kurma, alpokat, jambu, naga merah, pir, sawo,...
#
# [1023 rows x 2 columns]

# %%
# Create the rules# Create 
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=0)
rules
# Out:
#      antecedents   consequents  antecedent support  consequent support  \
# 0        (Jeruk)      (Anggur)            0.396985            0.422111
# 1       (Anggur)       (Jeruk)            0.422111            0.396985
# 2      (alpokat)      (Anggur)            0.402010            0.422111
# 3       (Anggur)     (alpokat)            0.422111            0.402010
# 4        (jambu)      (Anggur)            0.437186            0.422111
# 5       (Anggur)       (jambu)            0.422111            0.437186
# 6        (kurma)      (Anggur)            0.412060            0.422111
# 7       (Anggur)       (kurma)            0.422111            0.412060
# 8       (mangga)      (Anggur)            0.391960            0.422111
# 9       (Anggur)      (mangga)            0.422111            0.391960
# 10      (Anggur)  (naga merah)            0.422111            0.422111
# 11  (naga merah)      (Anggur)            0.422111            0.422111
# 12      (Anggur)         (pir)            0.422111            0.376884
# 13         (pir)      (Anggur)            0.376884            0.422111
# 14      (pisang)      (Anggur)            0.417085            0.422111
# 15      (Anggur)      (pisang)            0.422111            0.417085
# 16      (Anggur)        (sawo)            0.422111            0.447236
# 17        (sawo)      (Anggur)            0.447236            0.422111
# 18       (Jeruk)     (alpokat)            0.396985            0.402010
# 19     (alpokat)       (Jeruk)            0.402010            0.396985
# 20       (Jeruk)       (jambu)            0.396985            0.437186
# 21       (jambu)       (Jeruk)            0.437186            0.396985
# 22       (kurma)       (Jeruk)            0.412060            0.396985
# 23       (Jeruk)       (kurma)            0.396985            0.412060
# 24      (mangga)       (Jeruk)            0.391960            0.396985
# 25       (Jeruk)      (mangga)            0.396985            0.391960
# 26       (Jeruk)  (naga merah)            0.396985            0.422111
# 27  (naga merah)       (Jeruk)            0.422111            0.396985
# 28       (Jeruk)         (pir)            0.396985            0.376884
# 29         (pir)       (Jeruk)            0.376884            0.396985
# ..           ...           ...                 ...                 ...
# 58       (jambu)        (sawo)            0.437186            0.447236
# 59        (sawo)       (jambu)            0.447236            0.437186
# 60      (mangga)       (kurma)            0.391960            0.412060
# 61       (kurma)      (mangga)            0.412060            0.391960
# 62       (kurma)  (naga merah)            0.412060            0.422111
# 63  (naga merah)       (kurma)            0.422111            0.412060
# 64       (kurma)         (pir)            0.412060            0.376884
# 65         (pir)       (kurma)            0.376884            0.412060
# 66      (pisang)       (kurma)            0.417085            0.412060
# 67       (kurma)      (pisang)            0.412060            0.417085
# 68       (kurma)        (sawo)            0.412060            0.447236
# 69        (sawo)       (kurma)            0.447236            0.412060
# 70      (mangga)  (naga merah)            0.391960            0.422111
# 71  (naga merah)      (mangga)            0.422111            0.391960
# 72      (mangga)         (pir)            0.391960            0.376884
# 73         (pir)      (mangga)            0.376884            0.391960
# 74      (pisang)      (mangga)            0.417085            0.391960
# 75      (mangga)      (pisang)            0.391960            0.417085
# 76      (mangga)        (sawo)            0.391960            0.447236
# 77        (sawo)      (mangga)            0.447236            0.391960
# 78         (pir)  (naga merah)            0.376884            0.422111
# 79  (naga merah)         (pir)            0.422111            0.376884
# 80      (pisang)  (naga merah)            0.417085            0.422111
# 81  (naga merah)      (pisang)            0.422111            0.417085
# 82  (naga merah)        (sawo)            0.422111            0.447236
# 83        (sawo)  (naga merah)            0.447236            0.422111
# 84         (pir)        (sawo)            0.376884            0.447236
# 85        (sawo)         (pir)            0.447236            0.376884
# 86      (pisang)        (sawo)            0.417085            0.447236
# 87        (sawo)      (pisang)            0.447236            0.417085
#
#      support  confidence      lift  leverage  conviction
# 0   0.130653    0.329114  0.779687 -0.036918    0.861382
# 1   0.130653    0.309524  0.779687 -0.036918    0.873332
# 2   0.150754    0.375000  0.888393 -0.018939    0.924623
# 3   0.150754    0.357143  0.888393 -0.018939    0.930207
# 4   0.150754    0.344828  0.816913 -0.033787    0.882042
# 5   0.150754    0.357143  0.816913 -0.033787    0.875489
# 6   0.145729    0.353659  0.837834 -0.028206    0.894093
# 7   0.145729    0.345238  0.837834 -0.028206    0.897944
# 8   0.150754    0.384615  0.911172 -0.014697    0.939070
# 9   0.150754    0.357143  0.911172 -0.014697    0.945840
# 10  0.165829    0.392857  0.930697 -0.012348    0.951818
# 11  0.165829    0.392857  0.930697 -0.012348    0.951818
# 12  0.155779    0.369048  0.979206 -0.003308    0.987579
# 13  0.155779    0.413333  0.979206 -0.003308    0.985039
# 14  0.190955    0.457831  1.084624  0.014899    1.065885
# 15  0.190955    0.452381  1.084624  0.014899    1.064453
# 16  0.160804    0.380952  0.851792 -0.027979    0.892926
# 17  0.160804    0.359551  0.851792 -0.027979    0.902319
# 18  0.150754    0.379747  0.944620 -0.008838    0.964106
# 19  0.150754    0.375000  0.944620 -0.008838    0.964824
# 20  0.155779    0.392405  0.897570 -0.017777    0.926298
# 21  0.155779    0.356322  0.897570 -0.017777    0.936827
# 22  0.165829    0.402439  1.013739  0.002247    1.009127
# 23  0.165829    0.417722  1.013739  0.002247    1.009723
# 24  0.135678    0.346154  0.871957 -0.019924    0.922258
# 25  0.135678    0.341772  0.871957 -0.019924    0.923753
# 26  0.150754    0.379747  0.899638 -0.016818    0.931699
# 27  0.150754    0.357143  0.899638 -0.016818    0.938023
# 28  0.125628    0.316456  0.839662 -0.023989    0.911595
# 29  0.125628    0.333333  0.839662 -0.023989    0.904523
# ..       ...         ...       ...       ...         ...
# 58  0.170854    0.390805  0.873822 -0.024671    0.907367
# 59  0.170854    0.382022  0.873822 -0.024671    0.910735
# 60  0.130653    0.333333  0.808943 -0.030858    0.881910
# 61  0.130653    0.317073  0.808943 -0.030858    0.890345
# 62  0.140704    0.341463  0.808943 -0.033231    0.877536
# 63  0.140704    0.333333  0.808943 -0.033231    0.881910
# 64  0.125628    0.304878  0.808943 -0.029671    0.896412
# 65  0.125628    0.333333  0.808943 -0.029671    0.881910
# 66  0.130653    0.313253  0.760212 -0.041211    0.856123
# 67  0.130653    0.317073  0.760212 -0.041211    0.853553
# 68  0.155779    0.378049  0.845300 -0.028509    0.888758
# 69  0.155779    0.348315  0.845300 -0.028509    0.902183
# 70  0.130653    0.333333  0.789683 -0.034797    0.866834
# 71  0.130653    0.309524  0.789683 -0.034797    0.880610
# 72  0.130653    0.333333  0.884444 -0.017070    0.934673
# 73  0.130653    0.346667  0.884444 -0.017070    0.930674
# 74  0.155779    0.373494  0.952888 -0.007702    0.970526
# 75  0.155779    0.397436  0.952888 -0.007702    0.967390
# 76  0.160804    0.410256  0.917315 -0.014495    0.937295
# 77  0.160804    0.359551  0.917315 -0.014495    0.949396
# 78  0.125628    0.333333  0.789683 -0.033459    0.866834
# 79  0.125628    0.297619  0.789683 -0.033459    0.887148
# 80  0.175879    0.421687  0.998996 -0.000177    0.999267
# 81  0.175879    0.416667  0.998996 -0.000177    0.999282
# 82  0.160804    0.380952  0.851792 -0.027979    0.892926
# 83  0.160804    0.359551  0.851792 -0.027979    0.902319
# 84  0.155779    0.413333  0.924195 -0.012777    0.942211
# 85  0.155779    0.348315  0.924195 -0.012777    0.956160
# 86  0.180905    0.433735  0.969812 -0.005631    0.976157
# 87  0.180905    0.404494  0.969812 -0.005631    0.978857
#
# [88 rows x 9 columns]

# %%
rules.shape
# Out:
# (4, 9)

# %%
rules[ (rules['lift'] >= 1) &
       (rules['confidence'] >= 0.4) ]
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0    (pisang)    (Anggur)            0.417085            0.422111  0.190955
# 1    (Anggur)    (pisang)            0.422111            0.417085  0.190955
# 2     (Jeruk)     (kurma)            0.396985            0.412060  0.165829
# 3     (kurma)     (Jeruk)            0.412060            0.396985  0.165829
#
#    confidence      lift  leverage  conviction
# 0    0.457831  1.084624  0.014899    1.065885
# 1    0.452381  1.084624  0.014899    1.064453
# 2    0.417722  1.013739  0.002247    1.009723
# 3    0.402439  1.013739  0.002247    1.009127

# %%
rules.to_csv('rule.csv', index=False)
